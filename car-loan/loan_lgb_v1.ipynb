# %%
#!/usr/bin/env python
# coding: utf-8


# 导入第三方包
import pandas as pd
import numpy as np

import lightgbm as lgb

from sklearn.model_selection import KFold
from sklearn.metrics import f1_score, roc_auc_score

import warnings
warnings.filterwarnings('ignore')



# 读取数据集，具体下载方式可见操作手册
train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')

sample_submit = pd.read_csv('dataset/submit.csv')


# 训练数据及测试数据准备
all_cols = [f for f in train.columns if f not in ['customer_id','loan_default']]

x_train = train[all_cols]
x_test = test[all_cols]

y_train = train['loan_default']


# 作为baseline部分仅使用经典的**LightGBM**作为训练模型，我们还能尝试**XGBoost、CatBoost和NN（神经网络）**
def cv_model(clf, train_x, train_y, test_x, clf_name='lgb'):
    folds = 5
    seed = 2021
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    train = np.zeros(train_x.shape[0])
    test = np.zeros(test_x.shape[0])

    cv_scores = []

    for i, (train_index, valid_index) in enumerate(kf.split(train_x, train_y)):
        print('************************************ {} ************************************'.format(str(i+1)))
        trn_x, trn_y, val_x, val_y = train_x.iloc[train_index], train_y[train_index], train_x.iloc[valid_index], train_y[valid_index]

        train_matrix = clf.Dataset(trn_x, label=trn_y)
        valid_matrix = clf.Dataset(val_x, label=val_y)

        params = {
            'boosting_type': 'gbdt',
            'objective': 'binary',
            'metric': 'auc',
            'min_child_weight': 5,
            'num_leaves': 15,
            'max_depth':4,
            'lambda_l2': 8,
            'feature_fraction': 0.9,
            'bagging_fraction': 0.9,
            'bagging_freq': 7,
            'learning_rate': 0.01,
            'seed': 2021,
            'num_threads': 8,
            'n_jobs':-1,
            'silent': False,
            'verbose': -1,
        }

        model = clf.train(params, train_matrix, 20000, valid_sets=[train_matrix, valid_matrix], verbose_eval=500,early_stopping_rounds=200)
        val_pred = model.predict(val_x, num_iteration=model.best_iteration)
        test_pred = model.predict(test_x, num_iteration=model.best_iteration)

        # print(list(sorted(zip(features, model.feature_importance("gain")), key=lambda x: x[1], reverse=True))[:20])

        train[valid_index] = val_pred
        test += test_pred / kf.n_splits
        cv_scores.append(roc_auc_score(val_y, val_pred))
        
        print(cv_scores)
       
    print("%s_scotrainre_list:" % clf_name, cv_scores)
    print("%s_score_mean:" % clf_name, np.mean(cv_scores))
    print("%s_score_std:" % clf_name, np.std(cv_scores))
    return train, test



lgb_train, lgb_test = cv_model(lgb, x_train, y_train, x_test)


# 预测结果
sample_submit['loan_default'] = lgb_test
sample_submit['loan_default'] = sample_submit['loan_default'].apply(lambda x:1 if x>0.25 else 0).values
sample_submit.to_csv('loan_lgb_dart_v1.csv', index=False)
# Out:
# ************************************ 1 ************************************
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
# Training until validation scores don't improve for 200 rounds
# [500]	training's auc: 0.662153	valid_1's auc: 0.651783
# [1000]	training's auc: 0.67662	valid_1's auc: 0.659996
# [1500]	training's auc: 0.68667	valid_1's auc: 0.663094
# [2000]	training's auc: 0.694231	valid_1's auc: 0.664652
# [2500]	training's auc: 0.700785	valid_1's auc: 0.66516
# Early stopping, best iteration is:
# [2395]	training's auc: 0.69948	valid_1's auc: 0.665187
# [0.6651869227785964]
# ************************************ 2 ************************************
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
# Training until validation scores don't improve for 200 rounds
# [500]	training's auc: 0.662321	valid_1's auc: 0.65008
# [1000]	training's auc: 0.676629	valid_1's auc: 0.657697
# [1500]	training's auc: 0.685888	valid_1's auc: 0.660963
# [2000]	training's auc: 0.693923	valid_1's auc: 0.662807
# [2500]	training's auc: 0.700399	valid_1's auc: 0.663978
# [3000]	training's auc: 0.705961	valid_1's auc: 0.664144
# Early stopping, best iteration is:
# [2866]	training's auc: 0.70446	valid_1's auc: 0.664249
# [0.6651869227785964, 0.6642489285593391]
# ************************************ 3 ************************************
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
# Training until validation scores don't improve for 200 rounds
# [500]	training's auc: 0.660345	valid_1's auc: 0.651907
# [1000]	training's auc: 0.676307	valid_1's auc: 0.660219
# [1500]	training's auc: 0.686199	valid_1's auc: 0.663402
# [2000]	training's auc: 0.693565	valid_1's auc: 0.664985
# [2500]	training's auc: 0.700052	valid_1's auc: 0.665352
# Early stopping, best iteration is:
# [2310]	training's auc: 0.697859	valid_1's auc: 0.665489
# [0.6651869227785964, 0.6642489285593391, 0.6654888108076954]
# ************************************ 4 ************************************
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
# Training until validation scores don't improve for 200 rounds
# [500]	training's auc: 0.664402	valid_1's auc: 0.637568
# [1000]	training's auc: 0.678594	valid_1's auc: 0.645525
# [1500]	training's auc: 0.688454	valid_1's auc: 0.648961
# [2000]	training's auc: 0.695684	valid_1's auc: 0.650878
# [2500]	training's auc: 0.702271	valid_1's auc: 0.651879
# Early stopping, best iteration is:
# [2338]	training's auc: 0.700271	valid_1's auc: 0.652089
# [0.6651869227785964, 0.6642489285593391, 0.6654888108076954, 0.6520891044160053]
# ************************************ 5 ************************************
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
# Training until validation scores don't improve for 200 rounds
# [500]	training's auc: 0.661845	valid_1's auc: 0.650879
# [1000]	training's auc: 0.677454	valid_1's auc: 0.657292
# [1500]	training's auc: 0.686999	valid_1's auc: 0.659927
# [2000]	training's auc: 0.694566	valid_1's auc: 0.661079
# [2500]	training's auc: 0.700906	valid_1's auc: 0.661591
# Early stopping, best iteration is:
# [2332]	training's auc: 0.699017	valid_1's auc: 0.661657
# [0.6651869227785964, 0.6642489285593391, 0.6654888108076954, 0.6520891044160053, 0.661657235260432]
# lgb_scotrainre_list: [0.6651869227785964, 0.6642489285593391, 0.6654888108076954, 0.6520891044160053, 0.661657235260432]
# lgb_score_mean: 0.6617342003644137
# lgb_score_std: 0.005007515332493493
